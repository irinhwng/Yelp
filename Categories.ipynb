# %%
import pandas as pd

# %% [markdown]
# # Let's import `west_df.csv` to create binary columns of shop categories

# %%
df = pd.read_csv('./datasets/west_df.csv')
df.head()
# Out:
#    Unnamed: 0   category1  category2    category3 category4 category5  \
# 0           0     mexican          ?            ?         ?         ?
# 1           2    desserts  chocolate            ?         ?         ?
# 2           4  foodtrucks    mexican            ?         ?         ?
# 3           6    bakeries   cupcakes  customcakes         ?         ?
# 4           8     mexican          ?            ?         ?         ?
#
#           city   latitude   longitude  price  rating  zip_code
# 0  Los Angeles  33.974990 -118.246960    1.0     3.5     90001
# 1  Los Angeles  33.973630 -118.249890    2.0     5.0     90001
# 2  Los Angeles  34.060716 -118.344931    1.0     4.5     90017
# 3  Los Angeles  33.974865 -118.240467    2.0     4.0     90001
# 4   South Gate  33.956748 -118.223968    1.0     4.0     90280

# %%
df.shape
# Out:
# (69335, 12)

# %%
cats = ['category1', 'category2', 'category3', 'category4', 'category5', 'zip_code']
cat_df = df[cats]
cat_df.head()
# Out:
#     category1  category2    category3 category4 category5  zip_code
# 0     mexican          ?            ?         ?         ?     90001
# 1    desserts  chocolate            ?         ?         ?     90001
# 2  foodtrucks    mexican            ?         ?         ?     90017
# 3    bakeries   cupcakes  customcakes         ?         ?     90001
# 4     mexican          ?            ?         ?         ?     90280

# %%
categories_df = cat_df.astype(str).groupby('zip_code').agg(lambda x: ' '.join(x.unique()))

# %%
categories_df.head()
# Out:
#                                                   category1  \
# zip_code
# 90000                                                 salad
# 90001     mexican desserts bakeries foodtrucks burgers p...
# 90002                             salvadoran chinese coffee
# 90003     mexican foodtrucks soulfood bakeries pizza sea...
# 90004     bakeries salvadoran sushi coffee breakfast_bru...
#
#                                                   category2  \
# zip_code
# 90000                                          tradamerican
# 90001     ? chocolate cupcakes seafood comfortfood mexic...
# 90002                          ? juicebars breakfast_brunch
# 90003     foodstands mexican ? noodles sandwiches soulfo...
# 90004     coffee ? cafes vegan comfortfood chinese korea...
#
#                                                   category3 category4  \
# zip_code
# 90000                                                 wraps         ?
# 90001     ? customcakes sandwiches hotdog catering comfo...         ?
# 90002                                            ? desserts         ?
# 90003                       ? tradamerican waffles soulfood         ?
# 90004     cakeshop ? vegetarian soup noodles korean germ...         ?
#
#          category5
# zip_code
# 90000            ?
# 90001            ?
# 90002            ?
# 90003            ?
# 90004            ?

# %%
categories_df.shape
# Out:
# (2655, 5)

# %%
#combining all category columns together in order to turn into lists 
categories_df['all'] = categories_df['category1'] + ' ' + categories_df['category2'] + ' ' + categories_df['category3'] + ' ' + categories_df['category4'] + ' ' + categories_df['category5']

# %%
categories_df.head()
# Out:
#                                                   category1  \
# zip_code
# 90000                                                 salad
# 90001     mexican desserts bakeries foodtrucks burgers p...
# 90002                             salvadoran chinese coffee
# 90003     mexican foodtrucks soulfood bakeries pizza sea...
# 90004     bakeries salvadoran sushi coffee breakfast_bru...
#
#                                                   category2  \
# zip_code
# 90000                                          tradamerican
# 90001     ? chocolate cupcakes seafood comfortfood mexic...
# 90002                          ? juicebars breakfast_brunch
# 90003     foodstands mexican ? noodles sandwiches soulfo...
# 90004     coffee ? cafes vegan comfortfood chinese korea...
#
#                                                   category3 category4  \
# zip_code
# 90000                                                 wraps         ?
# 90001     ? customcakes sandwiches hotdog catering comfo...         ?
# 90002                                            ? desserts         ?
# 90003                       ? tradamerican waffles soulfood         ?
# 90004     cakeshop ? vegetarian soup noodles korean germ...         ?
#
#          category5                                                all
# zip_code
# 90000            ?                       salad tradamerican wraps ? ?
# 90001            ?  mexican desserts bakeries foodtrucks burgers p...
# 90002            ?  salvadoran chinese coffee ? juicebars breakfas...
# 90003            ?  mexican foodtrucks soulfood bakeries pizza sea...
# 90004            ?  bakeries salvadoran sushi coffee breakfast_bru...

# %%
categories_df['all'][0].split(' ')
# Out:
# ['salad', 'tradamerican', 'wraps', '?', '?']

# %%
import numpy as np

# %% [markdown]
# # Getting unique categories for each zip code

# %%
categories_df['list_cat'] = categories_df['all'].str.split(' ').apply(np.unique)

# %%
categories_df.head()
# Out:
#                                                   category1  \
# zip_code
# 90000                                                 salad
# 90001     mexican desserts bakeries foodtrucks burgers p...
# 90002                             salvadoran chinese coffee
# 90003     mexican foodtrucks soulfood bakeries pizza sea...
# 90004     bakeries salvadoran sushi coffee breakfast_bru...
#
#                                                   category2  \
# zip_code
# 90000                                          tradamerican
# 90001     ? chocolate cupcakes seafood comfortfood mexic...
# 90002                          ? juicebars breakfast_brunch
# 90003     foodstands mexican ? noodles sandwiches soulfo...
# 90004     coffee ? cafes vegan comfortfood chinese korea...
#
#                                                   category3 category4  \
# zip_code
# 90000                                                 wraps         ?
# 90001     ? customcakes sandwiches hotdog catering comfo...         ?
# 90002                                            ? desserts         ?
# 90003                       ? tradamerican waffles soulfood         ?
# 90004     cakeshop ? vegetarian soup noodles korean germ...         ?
#
#          category5                                                all  \
# zip_code
# 90000            ?                       salad tradamerican wraps ? ?
# 90001            ?  mexican desserts bakeries foodtrucks burgers p...
# 90002            ?  salvadoran chinese coffee ? juicebars breakfas...
# 90003            ?  mexican foodtrucks soulfood bakeries pizza sea...
# 90004            ?  bakeries salvadoran sushi coffee breakfast_bru...
#
#                                                    list_cat
# zip_code
# 90000                       [?, salad, tradamerican, wraps]
# 90001     [?, bakeries, breakfast_brunch, burgers, cater...
# 90002     [?, breakfast_brunch, chinese, coffee, dessert...
# 90003     [?, bakeries, bbq, breakfast_brunch, burgers, ...
# 90004     [?, asianfusion, bakeries, bbq, beer_and_wine,...

# %%
#sanity check
categories_df['list_cat'][50]
# Out:
# array(['?', 'breakfast_brunch', 'cafes', 'cocktailbars', 'coffee',
#        'foodtrucks', 'italian', 'mexican', 'poke', 'salad', 'sandwiches',
#        'sportsbars', 'streetvendors', 'tradamerican', 'venues'],
#       dtype='<U16')

# %% [markdown]
# # Creating an object containing unique categories of ALL zipcodes

# %%
unique_cats = categories_df['list_cat'].apply(pd.Series).stack().unique()

# %%
len(unique_cats)
# Out:
# 469

# %%
type(unique_cats)
# Out:
# numpy.ndarray

# %%
#sanity check 
'mexican' in unique_cats
# Out:
# True

# %%
for word in categories_df['list_cat'][0]:
    print(word)
# Out:
# ?
# salad
# tradamerican
# wraps

# %%
cat_dict = {}

def categorize(text):
  
    for word in text:
        #for category in unique_cats:
        if word in unique_cats:
            cat_dict[word] = 1
        else: 
            cat_dict[word] = 0
           
    return cat_dict

# %%
cat_dictionary = {}
def categorize(text):
    for category in unique_cats:
        #for cell in text:
            #for word in cell:
        if category in text:
            cat_dictionary[category] = 1
        else: 
            cat_dictionary[category] = 0
    return cat_dictionary

# %%
#creating new column from array to list 
categories_df['cat_list'] = categories_df['list_cat'].tolist()

# %%
categories_df.head()
# Out:
#                                                   category1  \
# zip_code
# 90000                                                 salad
# 90001     mexican desserts bakeries foodtrucks burgers p...
# 90002                             salvadoran chinese coffee
# 90003     mexican foodtrucks soulfood bakeries pizza sea...
# 90004     bakeries salvadoran sushi coffee breakfast_bru...
#
#                                                   category2  \
# zip_code
# 90000                                          tradamerican
# 90001     ? chocolate cupcakes seafood comfortfood mexic...
# 90002                          ? juicebars breakfast_brunch
# 90003     foodstands mexican ? noodles sandwiches soulfo...
# 90004     coffee ? cafes vegan comfortfood chinese korea...
#
#                                                   category3 category4  \
# zip_code
# 90000                                                 wraps         ?
# 90001     ? customcakes sandwiches hotdog catering comfo...         ?
# 90002                                            ? desserts         ?
# 90003                       ? tradamerican waffles soulfood         ?
# 90004     cakeshop ? vegetarian soup noodles korean germ...         ?
#
#          category5                                                all  \
# zip_code
# 90000            ?                       salad tradamerican wraps ? ?
# 90001            ?  mexican desserts bakeries foodtrucks burgers p...
# 90002            ?  salvadoran chinese coffee ? juicebars breakfas...
# 90003            ?  mexican foodtrucks soulfood bakeries pizza sea...
# 90004            ?  bakeries salvadoran sushi coffee breakfast_bru...
#
#                                                    list_cat  \
# zip_code
# 90000                       [?, salad, tradamerican, wraps]
# 90001     [?, bakeries, breakfast_brunch, burgers, cater...
# 90002     [?, breakfast_brunch, chinese, coffee, dessert...
# 90003     [?, bakeries, bbq, breakfast_brunch, burgers, ...
# 90004     [?, asianfusion, bakeries, bbq, beer_and_wine,...
#
#                                                    cat_list
# zip_code
# 90000                       [?, salad, tradamerican, wraps]
# 90001     [?, bakeries, breakfast_brunch, burgers, cater...
# 90002     [?, breakfast_brunch, chinese, coffee, dessert...
# 90003     [?, bakeries, bbq, breakfast_brunch, burgers, ...
# 90004     [?, asianfusion, bakeries, bbq, beer_and_wine,...

# %%
categories_df['cat_list'][5]
# Out:
# array(['?', 'argentine', 'asianfusion', 'bakeries', 'bars', 'bbq',
#        'beerbar', 'breakfast_brunch', 'bubbletea', 'burgers', 'cafes',
#        'chicken_wings', 'chickenshop', 'chinese', 'cocktailbars',
#        'coffee', 'desserts', 'donuts', 'empanadas', 'foodtrucks',
#        'hotdogs', 'hotpot', 'icecream', 'italian', 'izakaya', 'japanese',
#        'juicebars', 'karaoke', 'korean', 'latin', 'lounges',
#        'newamerican', 'noodles', 'peruvian', 'ramen', 'salvadoran',
#        'sandwiches', 'shavedice', 'soup', 'sportsbars', 'steak', 'sushi',
#        'tapasmallplates', 'thai', 'vietnamese'], dtype='<U16')

# %%
cat_df = categories_df['cat_list'].apply(categorize)

# %%
cat_df
# Out:
# zip_code
# 90000    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90001    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90002    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90003    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90004    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90005    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90006    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90007    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90008    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90010    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90011    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90012    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90013    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90014    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90015    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90016    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90017    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90018    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90019    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90020    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90021    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90022    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90023    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90024    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90025    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90026    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90027    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90028    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90029    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 90031    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
#                                ...
# 99686    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99688    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99692    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99693    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99701    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99702    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99703    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99705    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99707    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99709    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99712    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99714    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99723    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99737    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99743    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99755    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99775    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99780    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99801    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99821    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99824    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99827    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99829    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99830    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99833    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99835    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99840    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99901    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99921    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# 99929    {'?': 1, 'salad': 0, 'tradamerican': 0, 'wraps...
# Name: cat_list, Length: 2655, dtype: object

# %%
df = pd.DataFrame.from_dict(cat_df)

# %%
df['cat_list'][0]
# Out:
# {'?': 1,
#  'salad': 0,
#  'tradamerican': 0,
#  'wraps': 0,
#  'bakeries': 0,
#  'breakfast_brunch': 1,
#  'burgers': 1,
#  'catering': 0,
#  'chinese': 0,
#  'chocolate': 0,
#  'comfortfood': 0,
#  'cupcakes': 0,
#  'customcakes': 0,
#  'desserts': 0,
#  'foodtrucks': 0,
#  'gelato': 0,
#  'herbsandspices': 0,
#  'hotdog': 0,
#  'icecream': 0,
#  'japanese': 0,
#  'juicebars': 0,
#  'mexican': 0,
#  'pizza': 0,
#  'salvadoran': 0,
#  'sandwiches': 0,
#  'seafood': 0,
#  'seafoodmarkets': 0,
#  'streetvendors': 0,
#  'tacos': 0,
#  'vegan': 0,
#  'vietnamese': 0,
#  'coffee': 1,
#  'bbq': 0,
#  'fishnchips': 0,
#  'foodstands': 0,
#  'hotdogs': 1,
#  'latin': 0,
#  'noodles': 0,
#  'soulfood': 0,
#  'waffles': 0,
#  'asianfusion': 0,
#  'beer_and_wine': 0,
#  'cafes': 0,
#  'cakeshop': 0,
#  'cheese': 0,
#  'colombian': 0,
#  'gastropubs': 0,
#  'german': 0,
#  'gluten_free': 0,
#  'italian': 0,
#  'korean': 0,
#  'newamerican': 1,
#  'soup': 0,
#  'sushi': 0,
#  'tea': 0,
#  'thai': 0,
#  'vegetarian': 0,
#  'argentine': 0,
#  'bars': 1,
#  'beerbar': 0,
#  'bubbletea': 0,
#  'chicken_wings': 0,
#  'chickenshop': 0,
#  'cocktailbars': 0,
#  'donuts': 0,
#  'empanadas': 0,
#  'hotpot': 0,
#  'izakaya': 0,
#  'karaoke': 0,
#  'lounges': 0,
#  'peruvian': 0,
#  'ramen': 0,
#  'shavedice': 0,
#  'sportsbars': 0,
#  'steak': 1,
#  'tapasmallplates': 0,
#  'arts': 0,
#  'coffeeroasteries': 0,
#  'cuban': 0,
#  'divebars': 0,
#  'food': 0,
#  'gourmet': 0,
#  'greek': 0,
#  'grocery': 0,
#  'halal': 0,
#  'himalayan': 0,
#  'indpak': 0,
#  'mediterranean': 0,
#  'nicaraguan': 0,
#  'african': 0,
#  'beergardens': 0,
#  'buffets': 0,
#  'delis': 0,
#  'ethiopian': 0,
#  'hawaiian': 0,
#  'honduran': 0,
#  'irish_pubs': 0,
#  'mideastern': 0,
#  'popupshops': 0,
#  'restaurants': 0,
#  'southern': 0,
#  'taiwanese': 0,
#  'tex-mex': 0,
#  'turkish': 0,
#  'venues': 0,
#  'cajun': 0,
#  'cantonese': 0,
#  'caribbean': 0,
#  'brazilian': 0,
#  'cheesesteaks': 0,
#  'french': 0,
#  'japacurry': 0,
#  'mongolian': 0,
#  'pastashops': 0,
#  'poke': 0,
#  'wine_bars': 0,
#  'creperies': 0,
#  'indonesian': 0,
#  'breweries': 0,
#  'cambodian': 0,
#  'candy': 0,
#  'conveyorsushi': 0,
#  'dimsum': 0,
#  'diners': 0,
#  'filipino': 0,
#  'jazzandblues': 0,
#  'musicvenues': 0,
#  'panasian': 0,
#  'raw_food': 0,
#  'teppanyaki': 0,
#  'whiskeybars': 0,
#  'arcades': 0,
#  'bowling': 0,
#  'butcher': 0,
#  'danceclubs': 0,
#  'food_court': 0,
#  'galleries': 0,
#  'hookah_bars': 0,
#  'localflavor': 0,
#  'modern_european': 0,
#  'newmexican': 0,
#  'pubs': 0,
#  'tobaccoshops': 0,
#  'vitaminssupplements': 0,
#  'bagels': 0,
#  'gyms': 0,
#  'moroccan': 0,
#  'organic_stores': 0,
#  'persian': 0,
#  'falafel': 0,
#  'cafeteria': 0,
#  'meats': 0,
#  'acaibowls': 0,
#  'armenian': 0,
#  'healthmarkets': 0,
#  'irish': 0,
#  'lebanese': 0,
#  'suppliesrestaurant': 0,
#  'electronicsrepair': 0,
#  'kebab': 0,
#  'kosher': 0,
#  'mobilephonerepair': 0,
#  'scandinavian': 0,
#  'skatingrinks': 0,
#  'pakistani': 0,
#  'tapas': 0,
#  'markets': 0,
#  'popuprestaurants': 0,
#  'puertorican': 0,
#  'fooddeliveryservices': 0,
#  'poolhalls': 0,
#  'pharmacy': 0,
#  'macarons': 0,
#  'petadoption': 0,
#  'pretzels': 0,
#  'themedcafes': 0,
#  'bookstores': 0,
#  'brewpubs': 0,
#  'burmese': 0,
#  'tikibars': 0,
#  'brasseries': 0,
#  'british': 0,
#  'clubcrawl': 0,
#  'magicians': 0,
#  'polynesian': 0,
#  'speakeasies': 0,
#  'theater': 0,
#  'comedyclubs': 0,
#  'supperclubs': 0,
#  'convenience': 0,
#  'servicestations': 0,
#  'malaysian': 0,
#  'florists': 0,
#  'singaporean': 0,
#  'yoga': 0,
#  'museums': 0,
#  'bangladeshi': 0,
#  'bikerentals': 0,
#  'wineries': 0,
#  'herbalshops': 0,
#  'cookingschools': 0,
#  'airportlounges': 0,
#  'cookingclasses': 0,
#  'farmersmarket': 0,
#  'golf': 0,
#  'pancakes': 0,
#  'russian': 0,
#  'ukrainian': 0,
#  'basque': 0,
#  'spanish': 0,
#  'indoor_playcenter': 0,
#  'polish': 0,
#  'vintage': 0,
#  'szechuan': 0,
#  'gaybars': 0,
#  'medcenters': 0,
#  'cigarbars': 0,
#  'afghani': 0,
#  'egyptian': 0,
#  'smokehouse': 0,
#  'barbers': 0,
#  'waterstores': 0,
#  'nutritionists': 0,
#  'shavedsnow': 0,
#  'casinos': 0,
#  'diyfood': 0,
#  'australian': 0,
#  'internetcafe': 0,
#  'giftshops': 0,
#  'intlgrocery': 0,
#  'floraldesigners': 0,
#  'fondue': 0,
#  'hainan': 0,
#  'souvenirs': 0,
#  'beaches': 0,
#  'fashion': 0,
#  'shoes': 0,
#  'uzbek': 0,
#  'somali': 0,
#  'banks': 0,
#  'landmarks': 0,
#  'shoppingcenters': 0,
#  'eventplanning': 0,
#  'venezuelan': 0,
#  'shanghainese': 0,
#  'pianobars': 0,
#  'belgian': 0,
#  'dinnertheater': 0,
#  'virtualrealitycenters': 0,
#  'importedfood': 0,
#  'poolbilliards': 0,
#  'kombucha': 0,
#  'fleamarkets': 0,
#  'portuguese': 0,
#  'poutineries': 0,
#  'kids_activities': 0,
#  'syrian': 0,
#  'laotian': 0,
#  'winetasteclasses': 0,
#  'festivals': 0,
#  'hkcafe': 0,
#  'movietheaters': 0,
#  'drugstores': 0,
#  'champagne_bars': 0,
#  'pettingzoos': 0,
#  'pumpkinpatches': 0,
#  'oliveoil': 0,
#  'petstore': 0,
#  'eatertainment': 0,
#  'georgian': 0,
#  'partysupplies': 0,
#  'srilankan': 0,
#  'wedding_planning': 0,
#  'arabian': 0,
#  'vapeshops': 0,
#  'bike_repair_maintenance': 0,
#  'bikes': 0,
#  'acupuncture': 0,
#  'tcm': 0,
#  'sicilian': 0,
#  'musicians': 0,
#  'winetastingroom': 0,
#  'tabletopgames': 0,
#  'beverage_stores': 0,
#  'facepainting': 0,
#  'massage': 0,
#  'nonprofit': 0,
#  'partyequipmentrentals': 0,
#  'tuscan': 0,
#  'headshops': 0,
#  'kitchensupplies': 0,
#  'wholesale_stores': 0,
#  'guamanian': 0,
#  'othersalons': 0,
#  'waxing': 0,
#  'gardening': 0,
#  'gardens': 0,
#  'bartenders': 0,
#  'comicbooks': 0,
#  'hotels': 0,
#  'golfequipment': 0,
#  'golflessons': 0,
#  'localservices': 0,
#  'videoandgames': 0,
#  'nightlife': 0,
#  'specialtyschools': 0,
#  'toys': 0,
#  'cabaret': 0,
#  'personalchefs': 0,
#  'brewingsupplies': 0,
#  'southafrican': 0,
#  'distilleries': 0,
#  'artclasses': 0,
#  'paintandsip': 0,
#  'hungarian': 0,
#  'resorts': 0,
#  'antiques': 0,
#  'lasertag': 0,
#  'vinyl_records': 0,
#  'social_clubs': 0,
#  'deptstores': 0,
#  'weightlosscenters': 0,
#  'homedecor': 0,
#  'countrydancehalls': 0,
#  'waterdelivery': 0,
#  'hardware': 0,
#  'service_stations': 0,
#  'amusementparks': 0,
#  'travelservices': 0,
#  'spiritual_shop': 0,
#  'hiking': 0,
#  'bedbreakfast': 0,
#  'accessories': 0,
#  'outdoorgear': 0,
#  'rock_climbing': 0,
#  'hospitals': 0,
#  'popcorn': 0,
#  'childrensmuseums': 0,
#  'winetours': 0,
#  'boating': 0,
#  'jewelry': 0,
#  'cideries': 0,
#  'catalan': 0,
#  'publicmarkets': 0,
#  'piadina': 0,
#  'djs': 0,
#  'horseracing': 0,
#  'parks': 0,
#  'honey': 0,
#  'carwash': 0,
#  'huntingfishingsupplies': 0,
#  'bocceball': 0,
#  'pet_sitting': 0,
#  'personalassistants': 0,
#  'historicaltours': 0,
#  'vacation_rentals': 0,
#  'sportswear': 0,
#  'spas': 0,
#  'boatcharters': 0,
#  'postoffices': 0,
#  'mags': 0,
#  'skiresorts': 0,
#  'sportgoods': 0,
#  'menshair': 0,
#  'zoos': 0,
#  'musicvideo': 0,
#  'mailboxcenters': 0,
#  'fishing': 0,
#  'culturalcenter': 0,
#  'lancenters': 0,
#  'sharedofficespaces': 0,
#  'austrian': 0,
#  'czech': 0,
#  'mini_golf': 0,
#  'eritrean': 0,
#  'gardeners': 0,
#  'publicservicesgovt': 0,
#  'sardinian': 0,
#  'rvparks': 0,
#  'campgrounds': 0,
#  'guns_and_ammo': 0,
#  'threadingservices': 0,
#  'slovakian': 0,
#  'flowers': 0,
#  'opticians': 0,
#  'farms': 0,
#  'skateshops': 0,
#  'religiousitems': 0,
#  'visitorcenters': 0,
#  'bingo': 0,
#  'propane': 0,
#  'womenscloth': 0,
#  'massage_therapy': 0,
#  'hottubandpool': 0,
#  'saunas': 0,
#  'playgrounds': 0,
#  'attractionfarms': 0,
#  'ranches': 0,
#  'shopping': 0,
#  'escapegames': 0,
#  'beertours': 0,
#  'partybikerentals': 0,
#  'childcloth': 0,
#  'guesthouses': 0,
#  'usedbooks': 0,
#  'jewelryrepair': 0,
#  'paddleboarding': 0,
#  'scottish': 0,
#  'hostels': 0,
#  'tours': 0,
#  'walkingtours': 0,
#  'haitian': 0,
#  'musicalinstrumentsandteachers': 0,
#  'foodtours': 0,
#  'aquariums': 0,
#  'ayurveda': 0,
#  'beachequipmentrental': 0,
#  'yelpevents': 0,
#  'couriers': 0,
#  'churches': 0,
#  'media': 0,
#  'veteransorganizations': 0,
#  'recreation': 0,
#  'tanning': 0,
#  'contractors': 0,
#  'rafting': 0,
#  'cosmetics': 0,
#  'wholesalers': 0,
#  'discgolf': 0,
#  'interiordesign': 0,
#  'gamemeat': 0,
#  'recording_studios': 0,
#  'laundromat': 0,
#  'motorcyclinggear': 0,
#  'artsandcrafts': 0,
#  'lakes': 0,
#  'hotelstravel': 0,
#  'motorcycledealers': 0,
#  'mountainbiking': 0,
#  'sledding': 0,
#  'marinas': 0,
#  'hobbyshops': 0,
#  'swimmingpools': 0,
#  'preschools': 0,
#  'artmuseums': 0,
#  'trinidadian': 0,
#  'knittingsupplies': 0,
#  'senegalese': 0,
#  'dog_parks': 0,
#  'eventservices': 0,
#  'balloonservices': 0,
#  'paintyourownpottery': 0,
#  'adultedu': 0,
#  'pets': 0,
#  'shipping_centers': 0,
#  'pickyourown': 0,
#  'guitarstores': 0,
#  'artschools': 0,
#  'gokarts': 0,
#  'careercounseling': 0,
#  'artsupplies': 0,
#  'photoboothrentals': 0,
#  'hats': 0,
#  'education': 0,
#  'triviahosts': 0,
#  'tubing': 0,
#  'livestocksupply': 0,
#  'active': 0,
#  'landscaping': 0}

# %%
df['cat_list'][10]
# Out:
# {'?': 1,
#  'salad': 0,
#  'tradamerican': 0,
#  'wraps': 0,
#  'bakeries': 0,
#  'breakfast_brunch': 1,
#  'burgers': 1,
#  'catering': 0,
#  'chinese': 0,
#  'chocolate': 0,
#  'comfortfood': 0,
#  'cupcakes': 0,
#  'customcakes': 0,
#  'desserts': 0,
#  'foodtrucks': 0,
#  'gelato': 0,
#  'herbsandspices': 0,
#  'hotdog': 0,
#  'icecream': 0,
#  'japanese': 0,
#  'juicebars': 0,
#  'mexican': 0,
#  'pizza': 0,
#  'salvadoran': 0,
#  'sandwiches': 0,
#  'seafood': 0,
#  'seafoodmarkets': 0,
#  'streetvendors': 0,
#  'tacos': 0,
#  'vegan': 0,
#  'vietnamese': 0,
#  'coffee': 1,
#  'bbq': 0,
#  'fishnchips': 0,
#  'foodstands': 0,
#  'hotdogs': 1,
#  'latin': 0,
#  'noodles': 0,
#  'soulfood': 0,
#  'waffles': 0,
#  'asianfusion': 0,
#  'beer_and_wine': 0,
#  'cafes': 0,
#  'cakeshop': 0,
#  'cheese': 0,
#  'colombian': 0,
#  'gastropubs': 0,
#  'german': 0,
#  'gluten_free': 0,
#  'italian': 0,
#  'korean': 0,
#  'newamerican': 1,
#  'soup': 0,
#  'sushi': 0,
#  'tea': 0,
#  'thai': 0,
#  'vegetarian': 0,
#  'argentine': 0,
#  'bars': 1,
#  'beerbar': 0,
#  'bubbletea': 0,
#  'chicken_wings': 0,
#  'chickenshop': 0,
#  'cocktailbars': 0,
#  'donuts': 0,
#  'empanadas': 0,
#  'hotpot': 0,
#  'izakaya': 0,
#  'karaoke': 0,
#  'lounges': 0,
#  'peruvian': 0,
#  'ramen': 0,
#  'shavedice': 0,
#  'sportsbars': 0,
#  'steak': 1,
#  'tapasmallplates': 0,
#  'arts': 0,
#  'coffeeroasteries': 0,
#  'cuban': 0,
#  'divebars': 0,
#  'food': 0,
#  'gourmet': 0,
#  'greek': 0,
#  'grocery': 0,
#  'halal': 0,
#  'himalayan': 0,
#  'indpak': 0,
#  'mediterranean': 0,
#  'nicaraguan': 0,
#  'african': 0,
#  'beergardens': 0,
#  'buffets': 0,
#  'delis': 0,
#  'ethiopian': 0,
#  'hawaiian': 0,
#  'honduran': 0,
#  'irish_pubs': 0,
#  'mideastern': 0,
#  'popupshops': 0,
#  'restaurants': 0,
#  'southern': 0,
#  'taiwanese': 0,
#  'tex-mex': 0,
#  'turkish': 0,
#  'venues': 0,
#  'cajun': 0,
#  'cantonese': 0,
#  'caribbean': 0,
#  'brazilian': 0,
#  'cheesesteaks': 0,
#  'french': 0,
#  'japacurry': 0,
#  'mongolian': 0,
#  'pastashops': 0,
#  'poke': 0,
#  'wine_bars': 0,
#  'creperies': 0,
#  'indonesian': 0,
#  'breweries': 0,
#  'cambodian': 0,
#  'candy': 0,
#  'conveyorsushi': 0,
#  'dimsum': 0,
#  'diners': 0,
#  'filipino': 0,
#  'jazzandblues': 0,
#  'musicvenues': 0,
#  'panasian': 0,
#  'raw_food': 0,
#  'teppanyaki': 0,
#  'whiskeybars': 0,
#  'arcades': 0,
#  'bowling': 0,
#  'butcher': 0,
#  'danceclubs': 0,
#  'food_court': 0,
#  'galleries': 0,
#  'hookah_bars': 0,
#  'localflavor': 0,
#  'modern_european': 0,
#  'newmexican': 0,
#  'pubs': 0,
#  'tobaccoshops': 0,
#  'vitaminssupplements': 0,
#  'bagels': 0,
#  'gyms': 0,
#  'moroccan': 0,
#  'organic_stores': 0,
#  'persian': 0,
#  'falafel': 0,
#  'cafeteria': 0,
#  'meats': 0,
#  'acaibowls': 0,
#  'armenian': 0,
#  'healthmarkets': 0,
#  'irish': 0,
#  'lebanese': 0,
#  'suppliesrestaurant': 0,
#  'electronicsrepair': 0,
#  'kebab': 0,
#  'kosher': 0,
#  'mobilephonerepair': 0,
#  'scandinavian': 0,
#  'skatingrinks': 0,
#  'pakistani': 0,
#  'tapas': 0,
#  'markets': 0,
#  'popuprestaurants': 0,
#  'puertorican': 0,
#  'fooddeliveryservices': 0,
#  'poolhalls': 0,
#  'pharmacy': 0,
#  'macarons': 0,
#  'petadoption': 0,
#  'pretzels': 0,
#  'themedcafes': 0,
#  'bookstores': 0,
#  'brewpubs': 0,
#  'burmese': 0,
#  'tikibars': 0,
#  'brasseries': 0,
#  'british': 0,
#  'clubcrawl': 0,
#  'magicians': 0,
#  'polynesian': 0,
#  'speakeasies': 0,
#  'theater': 0,
#  'comedyclubs': 0,
#  'supperclubs': 0,
#  'convenience': 0,
#  'servicestations': 0,
#  'malaysian': 0,
#  'florists': 0,
#  'singaporean': 0,
#  'yoga': 0,
#  'museums': 0,
#  'bangladeshi': 0,
#  'bikerentals': 0,
#  'wineries': 0,
#  'herbalshops': 0,
#  'cookingschools': 0,
#  'airportlounges': 0,
#  'cookingclasses': 0,
#  'farmersmarket': 0,
#  'golf': 0,
#  'pancakes': 0,
#  'russian': 0,
#  'ukrainian': 0,
#  'basque': 0,
#  'spanish': 0,
#  'indoor_playcenter': 0,
#  'polish': 0,
#  'vintage': 0,
#  'szechuan': 0,
#  'gaybars': 0,
#  'medcenters': 0,
#  'cigarbars': 0,
#  'afghani': 0,
#  'egyptian': 0,
#  'smokehouse': 0,
#  'barbers': 0,
#  'waterstores': 0,
#  'nutritionists': 0,
#  'shavedsnow': 0,
#  'casinos': 0,
#  'diyfood': 0,
#  'australian': 0,
#  'internetcafe': 0,
#  'giftshops': 0,
#  'intlgrocery': 0,
#  'floraldesigners': 0,
#  'fondue': 0,
#  'hainan': 0,
#  'souvenirs': 0,
#  'beaches': 0,
#  'fashion': 0,
#  'shoes': 0,
#  'uzbek': 0,
#  'somali': 0,
#  'banks': 0,
#  'landmarks': 0,
#  'shoppingcenters': 0,
#  'eventplanning': 0,
#  'venezuelan': 0,
#  'shanghainese': 0,
#  'pianobars': 0,
#  'belgian': 0,
#  'dinnertheater': 0,
#  'virtualrealitycenters': 0,
#  'importedfood': 0,
#  'poolbilliards': 0,
#  'kombucha': 0,
#  'fleamarkets': 0,
#  'portuguese': 0,
#  'poutineries': 0,
#  'kids_activities': 0,
#  'syrian': 0,
#  'laotian': 0,
#  'winetasteclasses': 0,
#  'festivals': 0,
#  'hkcafe': 0,
#  'movietheaters': 0,
#  'drugstores': 0,
#  'champagne_bars': 0,
#  'pettingzoos': 0,
#  'pumpkinpatches': 0,
#  'oliveoil': 0,
#  'petstore': 0,
#  'eatertainment': 0,
#  'georgian': 0,
#  'partysupplies': 0,
#  'srilankan': 0,
#  'wedding_planning': 0,
#  'arabian': 0,
#  'vapeshops': 0,
#  'bike_repair_maintenance': 0,
#  'bikes': 0,
#  'acupuncture': 0,
#  'tcm': 0,
#  'sicilian': 0,
#  'musicians': 0,
#  'winetastingroom': 0,
#  'tabletopgames': 0,
#  'beverage_stores': 0,
#  'facepainting': 0,
#  'massage': 0,
#  'nonprofit': 0,
#  'partyequipmentrentals': 0,
#  'tuscan': 0,
#  'headshops': 0,
#  'kitchensupplies': 0,
#  'wholesale_stores': 0,
#  'guamanian': 0,
#  'othersalons': 0,
#  'waxing': 0,
#  'gardening': 0,
#  'gardens': 0,
#  'bartenders': 0,
#  'comicbooks': 0,
#  'hotels': 0,
#  'golfequipment': 0,
#  'golflessons': 0,
#  'localservices': 0,
#  'videoandgames': 0,
#  'nightlife': 0,
#  'specialtyschools': 0,
#  'toys': 0,
#  'cabaret': 0,
#  'personalchefs': 0,
#  'brewingsupplies': 0,
#  'southafrican': 0,
#  'distilleries': 0,
#  'artclasses': 0,
#  'paintandsip': 0,
#  'hungarian': 0,
#  'resorts': 0,
#  'antiques': 0,
#  'lasertag': 0,
#  'vinyl_records': 0,
#  'social_clubs': 0,
#  'deptstores': 0,
#  'weightlosscenters': 0,
#  'homedecor': 0,
#  'countrydancehalls': 0,
#  'waterdelivery': 0,
#  'hardware': 0,
#  'service_stations': 0,
#  'amusementparks': 0,
#  'travelservices': 0,
#  'spiritual_shop': 0,
#  'hiking': 0,
#  'bedbreakfast': 0,
#  'accessories': 0,
#  'outdoorgear': 0,
#  'rock_climbing': 0,
#  'hospitals': 0,
#  'popcorn': 0,
#  'childrensmuseums': 0,
#  'winetours': 0,
#  'boating': 0,
#  'jewelry': 0,
#  'cideries': 0,
#  'catalan': 0,
#  'publicmarkets': 0,
#  'piadina': 0,
#  'djs': 0,
#  'horseracing': 0,
#  'parks': 0,
#  'honey': 0,
#  'carwash': 0,
#  'huntingfishingsupplies': 0,
#  'bocceball': 0,
#  'pet_sitting': 0,
#  'personalassistants': 0,
#  'historicaltours': 0,
#  'vacation_rentals': 0,
#  'sportswear': 0,
#  'spas': 0,
#  'boatcharters': 0,
#  'postoffices': 0,
#  'mags': 0,
#  'skiresorts': 0,
#  'sportgoods': 0,
#  'menshair': 0,
#  'zoos': 0,
#  'musicvideo': 0,
#  'mailboxcenters': 0,
#  'fishing': 0,
#  'culturalcenter': 0,
#  'lancenters': 0,
#  'sharedofficespaces': 0,
#  'austrian': 0,
#  'czech': 0,
#  'mini_golf': 0,
#  'eritrean': 0,
#  'gardeners': 0,
#  'publicservicesgovt': 0,
#  'sardinian': 0,
#  'rvparks': 0,
#  'campgrounds': 0,
#  'guns_and_ammo': 0,
#  'threadingservices': 0,
#  'slovakian': 0,
#  'flowers': 0,
#  'opticians': 0,
#  'farms': 0,
#  'skateshops': 0,
#  'religiousitems': 0,
#  'visitorcenters': 0,
#  'bingo': 0,
#  'propane': 0,
#  'womenscloth': 0,
#  'massage_therapy': 0,
#  'hottubandpool': 0,
#  'saunas': 0,
#  'playgrounds': 0,
#  'attractionfarms': 0,
#  'ranches': 0,
#  'shopping': 0,
#  'escapegames': 0,
#  'beertours': 0,
#  'partybikerentals': 0,
#  'childcloth': 0,
#  'guesthouses': 0,
#  'usedbooks': 0,
#  'jewelryrepair': 0,
#  'paddleboarding': 0,
#  'scottish': 0,
#  'hostels': 0,
#  'tours': 0,
#  'walkingtours': 0,
#  'haitian': 0,
#  'musicalinstrumentsandteachers': 0,
#  'foodtours': 0,
#  'aquariums': 0,
#  'ayurveda': 0,
#  'beachequipmentrental': 0,
#  'yelpevents': 0,
#  'couriers': 0,
#  'churches': 0,
#  'media': 0,
#  'veteransorganizations': 0,
#  'recreation': 0,
#  'tanning': 0,
#  'contractors': 0,
#  'rafting': 0,
#  'cosmetics': 0,
#  'wholesalers': 0,
#  'discgolf': 0,
#  'interiordesign': 0,
#  'gamemeat': 0,
#  'recording_studios': 0,
#  'laundromat': 0,
#  'motorcyclinggear': 0,
#  'artsandcrafts': 0,
#  'lakes': 0,
#  'hotelstravel': 0,
#  'motorcycledealers': 0,
#  'mountainbiking': 0,
#  'sledding': 0,
#  'marinas': 0,
#  'hobbyshops': 0,
#  'swimmingpools': 0,
#  'preschools': 0,
#  'artmuseums': 0,
#  'trinidadian': 0,
#  'knittingsupplies': 0,
#  'senegalese': 0,
#  'dog_parks': 0,
#  'eventservices': 0,
#  'balloonservices': 0,
#  'paintyourownpottery': 0,
#  'adultedu': 0,
#  'pets': 0,
#  'shipping_centers': 0,
#  'pickyourown': 0,
#  'guitarstores': 0,
#  'artschools': 0,
#  'gokarts': 0,
#  'careercounseling': 0,
#  'artsupplies': 0,
#  'photoboothrentals': 0,
#  'hats': 0,
#  'education': 0,
#  'triviahosts': 0,
#  'tubing': 0,
#  'livestocksupply': 0,
#  'active': 0,
#  'landscaping': 0}
